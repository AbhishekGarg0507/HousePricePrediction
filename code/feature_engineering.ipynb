# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import datetime

from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("../data/cleaned_house_data.csv")

# %%
df
# Out:
#          energy                    heating    price    area  rooms   fee  \
# 0            Öl             Zentralheizung   249000   64.00      3  3.57
# 1           Gas  Fußbodenheizung, offener   1295000  136.06      4  3.57
# 2           Gas              Etagenheizung   770000  120.00      4  3.57
# 3           Gas             Zentralheizung   349000  158.00      5  3.57
# 4           Gas              Etagenheizung   494990  126.00      4  3.57
# ...         ...                        ...      ...     ...    ...   ...
# 4319  Fernwärme          Fußbodenheizung,    429000   78.00      3  3.57
# 4320        Gas             Zentralheizung   729000  150.00      4  3.57
# 4321        Gas              Etagenheizung   695600   94.00      3  3.57
# 4322  Fernwärme      Minergie zertifiziert   839251  107.00      3  3.57
# 4323         Öl             Zentralheizung   220000  125.06      3  3.57
#
#       zipcode  construction_year  level  price_per_area  \
# 0       13505               1971      2     3890.625000
# 1       10405               1900      5     9517.859768
# 2       12161               1900      5     6416.666667
# 3       12103               1956      1     2208.860759
# 4       12157               1909      3     3928.492063
# ...       ...                ...    ...             ...
# 4319    13595               2000      1     5500.000000
# 4320    13467               1990      1     4860.000000
# 4321    10115               1900      1     7400.000000
# 4322    13591               1894      1     7843.467290
# 4323    13591               1986      2     1759.155605
#
#                     heating_raw    heating_clean energy_clean
# 0                Zentralheizung   zentralheizung           öl
# 1     Fußbodenheizung, offener   fußbodenheizung          gas
# 2                 Etagenheizung    etagenheizung          gas
# 3                Zentralheizung   zentralheizung          gas
# 4                 Etagenheizung    etagenheizung          gas
# ...                         ...              ...          ...
# 4319          Fußbodenheizung,   fußbodenheizung    fernwärme
# 4320             Zentralheizung   zentralheizung          gas
# 4321              Etagenheizung    etagenheizung          gas
# 4322      Minergie zertifiziert         minergie    fernwärme
# 4323             Zentralheizung   zentralheizung           öl
#
# [4324 rows x 13 columns]

# %%
# House age

current_year = datetime.datetime.now().year
df['house_age'] = current_year - df['construction_year']

# %%
# price per area

df['price_per_area'] = df['price'] / df['area']

# %%
# rooms_per_area

df['rooms_per_area'] = df['rooms'] / df['area']

# %%
# one-hot encoding categorical columns

categorical_cols = ['heating_clean', 'energy_clean', 'level']
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# %%
print(df.columns)
# Out:
# Index(['energy', 'heating', 'price', 'area', 'rooms', 'fee', 'zipcode',
#        'construction_year', 'price_per_area', 'heating_raw', 'house_age',
#        'rooms_per_area', 'heating_clean_fußbodenheizung',
#        'heating_clean_minergie', 'heating_clean_missing',
#        'heating_clean_other', 'heating_clean_wärmepumpe',
#        'heating_clean_zentralheizung', 'energy_clean_gas',
#        'energy_clean_missing', 'energy_clean_other', 'energy_clean_öl',
#        'level_2', 'level_3', 'level_4', 'level_5', 'level_6', 'level_7',
#        'level_8', 'level_9', 'level_10', 'level_11', 'level_12', 'level_13',
#        'level_14', 'level_15', 'level_17', 'level_21', 'level_23', 'level_24',
#        'level_2023'],
#       dtype='object')

# %%
# Log-transform skewed numeric columns

df['log_price'] = np.log1p(df['price'])
df['log_area'] = np.log1p(df['area'])
df['log_fee'] = np.log1p(df['fee'].replace(0, np.nan))

# %%
# Binning house_age or rooms_per_area

df['age_bin'] = pd.cut(df['house_age'], bins=[0,10,30,50,100], labels=['new','recent','old','very_old'])
df['rooms_per_area_bin'] = pd.qcut(df['rooms_per_area'], q=4, labels=False)

# %%
# Calculate frequency of each zipcode
zipcode_freq = df['zipcode'].value_counts(normalize=True)

# Map frequencies back to the dataframe
df['zipcode_freq'] = df['zipcode'].map(zipcode_freq)

# %%
print(df.columns)
# Out:
# Index(['energy', 'heating', 'price', 'area', 'rooms', 'fee', 'zipcode',
#        'construction_year', 'price_per_area', 'heating_raw', 'house_age',
#        'rooms_per_area', 'heating_clean_fußbodenheizung',
#        'heating_clean_minergie', 'heating_clean_missing',
#        'heating_clean_other', 'heating_clean_wärmepumpe',
#        'heating_clean_zentralheizung', 'energy_clean_gas',
#        'energy_clean_missing', 'energy_clean_other', 'energy_clean_öl',
#        'level_2', 'level_3', 'level_4', 'level_5', 'level_6', 'level_7',
#        'level_8', 'level_9', 'level_10', 'level_11', 'level_12', 'level_13',
#        'level_14', 'level_15', 'level_17', 'level_21', 'level_23', 'level_24',
#        'level_2023', 'log_price', 'log_area', 'log_fee', 'age_bin',
#        'rooms_per_area_bin', 'zipcode_freq'],
#       dtype='object')

# %%
df.to_csv('FE_housing.csv', index=False)
